# %% [markdown]
# # Lesson 30: Extracting data of interest

# %% [markdown]
# *This tutorial was generated from a Jupyter notebook.  You can download the notebook [here](l30_frog_pandas.ipynb).*

# %%
# NumPy of course
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

# This is how we import the module of Matplotlib we'll be using
import matplotlib.pyplot as plt

# Seaborn makes plots pretty!
import seaborn as sns

# PyBeeswarm for some better data display
import beeswarm

# Magic function to make matplotlib inline; other style specs must come AFTER
# %matplotlib inline

# This enables SVG graphics inline (only use with static plots (non-Bokeh))
# %config InlineBackend.figure_format = 'svg'

# Set JB's favorite Seaborn settings
rc={'lines.linewidth': 2, 'axes.labelsize': 18, 'axes.titlesize': 18, 
    'axes.facecolor': 'DFDFE5'}
sns.set_context('notebook', rc=rc)

# %% [markdown]
# In the last lesson, we learned about Pandas and dipped our toe in to see its power.  In this lesson, we will work with a more complicated data set and use Pandas to handle it and pull out what we need.

# %% [markdown]
# ## The data set
# The data set comes from Kleinteich and Gorb, *Sci. Rep.*, **4**, 2014.  They measured several properties about the tongue strikes of horned frogs.  Let's rake a look at the data set, which you can download [here](../data/frog_tongue_adhesion.csv).

# %%
# Use ! to invoke a shell command. Use head to look at top 20 lines of file.
# !head -n 20 ../data/frog_tongue_adhesion.csv
# Out:
# # These data are from the paper,
# #   Kleinteich and Gorb, Sci. Rep., 4, 5225, 2014.
# # It was featured in the New York Times.
# #    http://www.nytimes.com/2014/08/25/science/a-frog-thats-a-living-breathing-pac-man.html
# #
# # The authors included the data in their supplemental information.
# #
# # Importantly, the ID refers to the identifites of the frogs they tested.
# #   I:   adult, 63 mm snout-vent-length (SVL) and 63.1 g body weight,
# #        Ceratophrys cranwelli crossed with Ceratophrys cornuta
# #   II:  adult, 70 mm SVL and 72.7 g body weight,
# #        Ceratophrys cranwelli crossed with Ceratophrys cornuta
# #   III: juvenile, 28 mm SVL and 12.7 g body weight, Ceratophrys cranwelli
# #   IV:  juvenile, 31 mm SVL and 12.7 g body weight, Ceratophrys cranwelli
# date,ID,trial number,impact force (mN),impact time (ms),impact force / body weight,adhesive force (mN),time frog pulls on target (ms),adhesive force / body weight,adhesive impulse (N-s),total contact area (mm2),contact area without mucus (mm2),contact area with mucus / contact area without mucus,contact pressure (Pa),adhesive strength (Pa)
# 2013_02_26,I,3,1205,46,1.95,-785,884,1.27,-0.290,387,70,0.82,3117,-2030
# 2013_02_26,I,4,2527,44,4.08,-983,248,1.59,-0.181,101,94,0.07,24923,-9695
# 2013_03_01,I,1,1745,34,2.82,-850,211,1.37,-0.157,83,79,0.05,21020,-10239
# 2013_03_01,I,2,1556,41,2.51,-455,1025,0.74,-0.170,330,158,0.52,4718,-1381
# 2013_03_01,I,3,493,36,0.80,-974,499,1.57,-0.423,245,216,0.12,2012,-3975

# %% [markdown]
# The first lines all begin with # signs, signifying that they are comments and not data. They do give important information, though, such as the meaning of the ID data. The ID refers to which specific frog was tested.
#
# Immediately after the comments, we have a row of comma-separated headers. This row sets the number of columns in this data set and labels the meaning of the columns. So, we see that the first column is the date of the experiment, the second column is the ID of the frog, the third is the trial number, and so on.
#
# After this row, each row repesents a single experiment where the frog struck the target.  So, these data are already in tidy format.  Let's go ahead and load the data into a `DataFrame`.

# %%
# Load the data
df = pd.read_csv('../data/frog_tongue_adhesion.csv', comment='#')

# Take a look
df
# Out:
#           date   ID  trial number  impact force (mN)  impact time (ms)  \
# 0   2013_02_26    I             3               1205                46
# 1   2013_02_26    I             4               2527                44
# 2   2013_03_01    I             1               1745                34
# 3   2013_03_01    I             2               1556                41
# 4   2013_03_01    I             3                493                36
# 5   2013_03_01    I             4               2276                31
# 6   2013_03_05    I             1                556                43
# 7   2013_03_05    I             2               1928                46
# 8   2013_03_05    I             3               2641                50
# 9   2013_03_05    I             4               1897                41
# 10  2013_03_12    I             1               1891                40
# 11  2013_03_12    I             2               1545                48
# 12  2013_03_12    I             3               1307                29
# 13  2013_03_12    I             4               1692                31
# 14  2013_03_12    I             5               1543                38
# 15  2013_03_15    I             1               1282                31
# 16  2013_03_15    I             2                775                34
# 17  2013_03_15    I             3               2032                60
# 18  2013_03_15    I             4               1240                34
# 19  2013_03_15    I             5                473                40
# 20  2013_03_19   II             1               1612                18
# 21  2013_03_19   II             2                605                55
# 22  2013_03_19   II             3                327                51
# 23  2013_03_19   II             4                946                59
# 24  2013_03_21   II             1                541                33
# 25  2013_03_21   II             2               1539                43
# 26  2013_03_21   II             3                529                28
# 27  2013_03_21   II             4                628                31
# 28  2013_03_25   II             1               1453                72
# 29  2013_03_25   II             2                297                42
# ..         ...  ...           ...                ...               ...
# 50  2013_06_18  III             3                458                30
# 51  2013_06_18  III             4                626                16
# 52  2013_06_21  III             1                621                27
# 53  2013_06_21  III             2                544                30
# 54  2013_06_21  III             3                535                35
# 55  2013_06_21  III             4                385                39
# 56  2013_06_26  III             1                401                36
# 57  2013_06_26  III             2                614                34
# 58  2013_06_26  III             3                665                40
# 59  2013_06_26  III             4                488                34
# 60  2013_05_27   IV             2                172                26
# 61  2013_05_27   IV             3                142                20
# 62  2013_05_27   IV             4                 37                55
# 63  2013_05_30   IV             1                453                38
# 64  2013_05_30   IV             2                355                31
# 65  2013_05_30   IV             3                 22                33
# 66  2013_06_03   IV             1                502                74
# 67  2013_06_11   IV             1                273                26
# 68  2013_06_11   IV             2                720                27
# 69  2013_06_11   IV             3                582                33
# 70  2013_06_11   IV             4                198                23
# 71  2013_06_14   IV             1                198                 6
# 72  2013_06_18   IV             1                597                29
# 73  2013_06_18   IV             2                516                31
# 74  2013_06_18   IV             3                815                34
# 75  2013_06_18   IV             4                402                38
# 76  2013_06_21   IV             1                605                39
# 77  2013_06_21   IV             2                711                76
# 78  2013_06_21   IV             3                614                33
# 79  2013_06_21   IV             4                468                36
#
#     impact force / body weight  adhesive force (mN)  \
# 0                         1.95                 -785
# 1                         4.08                 -983
# 2                         2.82                 -850
# 3                         2.51                 -455
# 4                         0.80                 -974
# 5                         3.68                 -592
# 6                         0.90                 -512
# 7                         3.11                 -804
# 8                         4.27                 -690
# 9                         3.06                 -462
# 10                        3.06                 -766
# 11                        2.50                 -715
# 12                        2.11                 -613
# 13                        2.73                 -677
# 14                        2.49                 -528
# 15                        2.07                 -452
# 16                        1.25                 -430
# 17                        3.28                 -652
# 18                        2.00                 -692
# 19                        0.76                 -536
# 20                        3.79                 -655
# 21                        1.42                 -292
# 22                        0.77                 -246
# 23                        2.23                 -245
# 24                        1.27                 -553
# 25                        3.62                 -664
# 26                        1.24                 -261
# 27                        1.48                 -691
# 28                        3.42                  -92
# 29                        0.70                 -566
# ..                         ...                  ...
# 50                        3.69                 -259
# 51                        5.04                 -231
# 52                        4.99                 -267
# 53                        4.38                 -178
# 54                        4.30                 -123
# 55                        3.09                 -151
# 56                        3.23                 -127
# 57                        4.94                 -372
# 58                        5.35                 -236
# 59                        3.93                 -390
# 60                        1.28                 -456
# 61                        1.05                 -193
# 62                        0.28                 -236
# 63                        3.37                 -225
# 64                        2.64                 -217
# 65                        0.17                 -161
# 66                        3.74                 -139
# 67                        2.03                 -264
# 68                        5.36                 -342
# 69                        4.34                 -231
# 70                        1.47                 -209
# 71                        1.47                 -292
# 72                        4.44                 -339
# 73                        3.84                 -371
# 74                        6.07                 -331
# 75                        3.00                 -302
# 76                        4.50                 -216
# 77                        5.30                 -163
# 78                        4.57                 -367
# 79                        3.48                 -218
#
#     time frog pulls on target (ms)  adhesive force / body weight  \
# 0                              884                          1.27
# 1                              248                          1.59
# 2                              211                          1.37
# 3                             1025                          0.74
# 4                              499                          1.57
# 5                              969                          0.96
# 6                              835                          0.83
# 7                              508                          1.30
# 8                              491                          1.12
# 9                              839                          0.75
# 10                            1069                          1.24
# 11                             649                          1.15
# 12                            1845                          0.99
# 13                             917                          1.09
# 14                             750                          0.85
# 15                             785                          0.73
# 16                             837                          0.70
# 17                             486                          1.05
# 18                             906                          1.12
# 19                            1218                          0.87
# 20                            3087                          1.54
# 21                            1261                          0.69
# 22                            1508                          0.58
# 23                            1841                          0.58
# 24                            3126                          1.30
# 25                             741                          1.56
# 26                            2482                          0.61
# 27                             998                          1.63
# 28                            1652                          0.22
# 29                             936                          1.33
# ..                             ...                           ...
# 50                             910                          2.08
# 51                             550                          1.86
# 52                            2081                          2.14
# 53                             376                          1.43
# 54                             289                          0.99
# 55                             607                          1.22
# 56                            2932                          1.02
# 57                             680                          2.99
# 58                             685                          1.90
# 59                            1308                          3.14
# 60                             462                          3.40
# 61                             250                          1.44
# 62                             743                          1.76
# 63                             844                          1.68
# 64                             728                          1.61
# 65                             472                          1.20
# 66                             959                          1.04
# 67                             844                          1.97
# 68                            1515                          2.55
# 69                             279                          1.72
# 70                            1427                          1.55
# 71                            2874                          2.17
# 72                            4251                          2.53
# 73                             626                          2.76
# 74                            1254                          2.47
# 75                             986                          2.25
# 76                            1627                          1.61
# 77                            2021                          1.21
# 78                            1366                          2.73
# 79                            1269                          1.63
#
#     adhesive impulse (N-s)  total contact area (mm2)  \
# 0                   -0.290                       387
# 1                   -0.181                       101
# 2                   -0.157                        83
# 3                   -0.170                       330
# 4                   -0.423                       245
# 5                   -0.176                       341
# 6                   -0.285                       359
# 7                   -0.285                       246
# 8                   -0.239                       269
# 9                   -0.328                       266
# 10                  -0.380                       408
# 11                  -0.298                       141
# 12                  -0.768                       455
# 13                  -0.457                       186
# 14                  -0.353                       153
# 15                  -0.253                       290
# 16                  -0.276                       257
# 17                  -0.257                       147
# 18                  -0.317                       364
# 19                  -0.382                       259
# 20                  -0.385                       348
# 21                  -0.294                       248
# 22                  -0.282                       130
# 23                  -0.340                       106
# 24                  -0.432                       276
# 25                  -0.046                        85
# 26                  -0.414                       325
# 27                  -0.071                       242
# 28                  -0.008                       136
# 29                  -0.084                       126
# ..                     ...                       ...
# 50                  -0.194                        91
# 51                  -0.042                        82
# 52                  -0.183                       120
# 53                  -0.034                        19
# 54                  -0.029                        21
# 55                  -0.082                        31
# 56                  -0.215                       142
# 57                  -0.140                        72
# 58                  -0.118                       129
# 59                  -0.208                       112
# 60                  -0.050                       133
# 61                  -0.047                        57
# 62                  -0.119                        51
# 63                  -0.110                       142
# 64                  -0.023                       174
# 65                  -0.052                        56
# 66                  -0.089                        65
# 67                  -0.160                       124
# 68                  -0.226                       137
# 69                  -0.033                        60
# 70                  -0.151                       110
# 71                  -0.232                       145
# 72                  -0.281                       191
# 73                  -0.094                        83
# 74                  -0.077                       151
# 75                  -0.122                       117
# 76                  -0.139                       123
# 77                  -0.217                       129
# 78                  -0.198                       128
# 79                  -0.122                       129
#
#     contact area without mucus (mm2)  \
# 0                                 70
# 1                                 94
# 2                                 79
# 3                                158
# 4                                216
# 5                                106
# 6                                110
# 7                                178
# 8                                224
# 9                                176
# 10                                33
# 11                               112
# 12                                92
# 13                               129
# 14                               148
# 15                               105
# 16                               124
# 17                               134
# 18                               260
# 19                               168
# 20                                15
# 21                                24
# 22                                34
# 23                                26
# 24                                16
# 25                                24
# 26                                33
# 27                                67
# 28                                 0
# 29                                 4
# ..                               ...
# 50                                88
# 51                                23
# 52                                58
# 53                                17
# 54                                29
# 55                               126
# 56                                12
# 57                                 1
# 58                                 0
# 59                                58
# 60                                 0
# 61                                74
# 62                                44
# 63                               108
# 64                                39
# 65                                 4
# 66                                77
# 67                                81
# 68                                 0
# 69                                 4
# 70                                69
# 71                                50
# 72                                12
# 73                                18
# 74                                20
# 75                                30
# 76                                20
# 77                                42
# 78                               108
# 79                                68
#
#     contact area with mucus / contact area without mucus  \
# 0                                                0.82
# 1                                                0.07
# 2                                                0.05
# 3                                                0.52
# 4                                                0.12
# 5                                                0.69
# 6                                                0.69
# 7                                                0.28
# 8                                                0.17
# 9                                                0.34
# 10                                               0.92
# 11                                               0.21
# 12                                               0.80
# 13                                               0.31
# 14                                               0.03
# 15                                               0.64
# 16                                               0.52
# 17                                               0.09
# 18                                               0.28
# 19                                               0.35
# 20                                               0.96
# 21                                               0.90
# 22                                               0.74
# 23                                               0.76
# 24                                               0.94
# 25                                               0.72
# 26                                               0.90
# 27                                               0.72
# 28                                               1.00
# 29                                               0.97
# ..                                                ...
# 50                                               0.15
# 51                                               0.01
# 52                                               0.90
# 53                                               0.05
# 54                                               0.05
# 55                                               0.03
# 56                                               0.86
# 57                                               0.42
# 58                                               0.16
# 59                                               0.39
# 60                                               0.88
# 61                                               0.83
# 62                                               0.54
# 63                                               0.48
# 64                                               0.98
# 65                                               0.02
# 66                                               0.91
# 67                                               0.29
# 68                                               0.83
# 69                                               0.03
# 70                                               0.84
# 71                                               0.99
# 72                                               1.00
# 73                                               0.12
# 74                                               0.71
# 75                                               0.07
# 76                                               1.00
# 77                                               0.97
# 78                                               0.46
# 79                                               0.61
#
#     contact pressure (Pa)  adhesive strength (Pa)
# 0                    3117                   -2030
# 1                   24923                   -9695
# 2                   21020                  -10239
# 3                    4718                   -1381
# 4                    2012                   -3975
# 5                    6676                   -1737
# 6                    1550                   -1427
# 7                    7832                   -3266
# 8                    9824                   -2568
# 9                    7122                   -1733
# 10                   4638                   -1879
# 11                  10947                   -5064
# 12                   2874                   -1348
# 13                   9089                   -3636
# 14                  10095                   -3453
# 15                   4419                   -1557
# 16                   3019                   -1677
# 17                  13784                   -4425
# 18                   3406                   -1901
# 19                   1830                   -2073
# 20                   4633                   -1881
# 21                   2441                   -1177
# 22                   2517                   -1894
# 23                   8893                   -2301
# 24                   1959                   -2004
# 25                  18073                   -7802
# 26                   1627                    -803
# 27                   2600                   -2860
# 28                  10645                    -678
# 29                   2367                   -4506
# ..                    ...                     ...
# 50                   5048                   -2855
# 51                   7633                   -2819
# 52                   5152                   -2213
# 53                  28641                   -9364
# 54                  25471                   -5843
# 55                  12409                   -4882
# 56                   2835                    -896
# 57                   8475                   -5136
# 58                   5171                   -1834
# 59                   4376                   -3492
# 60                   1297                   -3440
# 61                   2498                   -3400
# 62                    735                   -4647
# 63                   3177                   -1581
# 64                   2037                   -1245
# 65                    397                   -2866
# 66                   7713                   -2141
# 67                   2205                   -2136
# 68                   5259                   -2497
# 69                   9705                   -3847
# 70                   1793                   -1889
# 71                   1369                   -2018
# 72                   3116                   -1772
# 73                   6184                   -4447
# 74                   5386                   -2190
# 75                   3446                   -2591
# 76                   4928                   -1759
# 77                   5498                   -1257
# 78                   4776                   -2857
# 79                   3617                   -1688
#
# [80 rows x 15 columns]

# %% [markdown]
# ## Selecting data
# We can now access various subsets of the data.  For example, let's say we are only interested in strong stikes, i.e., those with an impact force above one Newton.  We just use Boolean slicing to get that out.

# %%
# Slice out big forces
df_big_force = df[df['impact force (mN)'] > 1000]

# Look at it
df_big_force
# Out:
#           date  ID  trial number  impact force (mN)  impact time (ms)  \
# 0   2013_02_26   I             3               1205                46
# 1   2013_02_26   I             4               2527                44
# 2   2013_03_01   I             1               1745                34
# 3   2013_03_01   I             2               1556                41
# 5   2013_03_01   I             4               2276                31
# 7   2013_03_05   I             2               1928                46
# 8   2013_03_05   I             3               2641                50
# 9   2013_03_05   I             4               1897                41
# 10  2013_03_12   I             1               1891                40
# 11  2013_03_12   I             2               1545                48
# 12  2013_03_12   I             3               1307                29
# 13  2013_03_12   I             4               1692                31
# 14  2013_03_12   I             5               1543                38
# 15  2013_03_15   I             1               1282                31
# 17  2013_03_15   I             3               2032                60
# 18  2013_03_15   I             4               1240                34
# 20  2013_03_19  II             1               1612                18
# 25  2013_03_21  II             2               1539                43
# 28  2013_03_25  II             1               1453                72
# 34  2013_04_03  II             1               1182                28
#
#     impact force / body weight  adhesive force (mN)  \
# 0                         1.95                 -785
# 1                         4.08                 -983
# 2                         2.82                 -850
# 3                         2.51                 -455
# 5                         3.68                 -592
# 7                         3.11                 -804
# 8                         4.27                 -690
# 9                         3.06                 -462
# 10                        3.06                 -766
# 11                        2.50                 -715
# 12                        2.11                 -613
# 13                        2.73                 -677
# 14                        2.49                 -528
# 15                        2.07                 -452
# 17                        3.28                 -652
# 18                        2.00                 -692
# 20                        3.79                 -655
# 25                        3.62                 -664
# 28                        3.42                  -92
# 34                        2.78                 -522
#
#     time frog pulls on target (ms)  adhesive force / body weight  \
# 0                              884                          1.27
# 1                              248                          1.59
# 2                              211                          1.37
# 3                             1025                          0.74
# 5                              969                          0.96
# 7                              508                          1.30
# 8                              491                          1.12
# 9                              839                          0.75
# 10                            1069                          1.24
# 11                             649                          1.15
# 12                            1845                          0.99
# 13                             917                          1.09
# 14                             750                          0.85
# 15                             785                          0.73
# 17                             486                          1.05
# 18                             906                          1.12
# 20                            3087                          1.54
# 25                             741                          1.56
# 28                            1652                          0.22
# 34                            1197                          1.23
#
#     adhesive impulse (N-s)  total contact area (mm2)  \
# 0                   -0.290                       387
# 1                   -0.181                       101
# 2                   -0.157                        83
# 3                   -0.170                       330
# 5                   -0.176                       341
# 7                   -0.285                       246
# 8                   -0.239                       269
# 9                   -0.328                       266
# 10                  -0.380                       408
# 11                  -0.298                       141
# 12                  -0.768                       455
# 13                  -0.457                       186
# 14                  -0.353                       153
# 15                  -0.253                       290
# 17                  -0.257                       147
# 18                  -0.317                       364
# 20                  -0.385                       348
# 25                  -0.046                        85
# 28                  -0.008                       136
# 34                  -0.118                       281
#
#     contact area without mucus (mm2)  \
# 0                                 70
# 1                                 94
# 2                                 79
# 3                                158
# 5                                106
# 7                                178
# 8                                224
# 9                                176
# 10                                33
# 11                               112
# 12                                92
# 13                               129
# 14                               148
# 15                               105
# 17                               134
# 18                               260
# 20                                15
# 25                                24
# 28                                 0
# 34                                 0
#
#     contact area with mucus / contact area without mucus  \
# 0                                                0.82
# 1                                                0.07
# 2                                                0.05
# 3                                                0.52
# 5                                                0.69
# 7                                                0.28
# 8                                                0.17
# 9                                                0.34
# 10                                               0.92
# 11                                               0.21
# 12                                               0.80
# 13                                               0.31
# 14                                               0.03
# 15                                               0.64
# 17                                               0.09
# 18                                               0.28
# 20                                               0.96
# 25                                               0.72
# 28                                               1.00
# 34                                               1.00
#
#     contact pressure (Pa)  adhesive strength (Pa)
# 0                    3117                   -2030
# 1                   24923                   -9695
# 2                   21020                  -10239
# 3                    4718                   -1381
# 5                    6676                   -1737
# 7                    7832                   -3266
# 8                    9824                   -2568
# 9                    7122                   -1733
# 10                   4638                   -1879
# 11                  10947                   -5064
# 12                   2874                   -1348
# 13                   9089                   -3636
# 14                  10095                   -3453
# 15                   4419                   -1557
# 17                  13784                   -4425
# 18                   3406                   -1901
# 20                   4633                   -1881
# 25                  18073                   -7802
# 28                  10645                    -678
# 34                   4213                   -1860

# %% [markdown]
# Notice that the indices of the individual measurements did not change!  This newly formed `DataFrame` does not have an index 4, for example.  You can think of the indices as labels on experiments/observations, not as the ordering in an array.  In fact, ordering is not really relevant at all in a `DataFrame`.

# %% [markdown]
# We can also select a single experiment (very convenient that the `DataFrame` is tidy!).  As we learned last time, we use the `ix` attribute of the `DataFrame`.

# %%
df.ix[42]
# Out:
# date                                                    2013_05_27
# ID                                                             III
# trial number                                                     3
# impact force (mN)                                              324
# impact time (ms)                                               105
# impact force / body weight                                    2.61
# adhesive force (mN)                                           -172
# time frog pulls on target (ms)                                 619
# adhesive force / body weight                                  1.38
# adhesive impulse (N-s)                                      -0.079
# total contact area (mm2)                                        55
# contact area without mucus (mm2)                                23
# contact area with mucus / contact area without mucus          0.37
# contact pressure (Pa)                                         5946
# adhesive strength (Pa)                                       -3149
# Name: 42, dtype: object

# %% [markdown]
# Conveniently, we get all the data and labels we need.
#
# We can select multiple columns by giving a list of column headers.

# %%
df[['impact force (mN)', 'adhesive force (mN)']]
# Out:
#     impact force (mN)  adhesive force (mN)
# 0                1205                 -785
# 1                2527                 -983
# 2                1745                 -850
# 3                1556                 -455
# 4                 493                 -974
# 5                2276                 -592
# 6                 556                 -512
# 7                1928                 -804
# 8                2641                 -690
# 9                1897                 -462
# 10               1891                 -766
# 11               1545                 -715
# 12               1307                 -613
# 13               1692                 -677
# 14               1543                 -528
# 15               1282                 -452
# 16                775                 -430
# 17               2032                 -652
# 18               1240                 -692
# 19                473                 -536
# 20               1612                 -655
# 21                605                 -292
# 22                327                 -246
# 23                946                 -245
# 24                541                 -553
# 25               1539                 -664
# 26                529                 -261
# 27                628                 -691
# 28               1453                  -92
# 29                297                 -566
# ..                ...                  ...
# 50                458                 -259
# 51                626                 -231
# 52                621                 -267
# 53                544                 -178
# 54                535                 -123
# 55                385                 -151
# 56                401                 -127
# 57                614                 -372
# 58                665                 -236
# 59                488                 -390
# 60                172                 -456
# 61                142                 -193
# 62                 37                 -236
# 63                453                 -225
# 64                355                 -217
# 65                 22                 -161
# 66                502                 -139
# 67                273                 -264
# 68                720                 -342
# 69                582                 -231
# 70                198                 -209
# 71                198                 -292
# 72                597                 -339
# 73                516                 -371
# 74                815                 -331
# 75                402                 -302
# 76                605                 -216
# 77                711                 -163
# 78                614                 -367
# 79                468                 -218
#
# [80 rows x 2 columns]

# %% [markdown]
# ## Finding correlations
# Now that we know how to slice out columns, we can start to find correlations.  For example, we might think that the impact force and the adhesive strength might be correlated.  Let's make a plot to check.

# %%
# Using Pandas automatically gives axis labels
df.plot(x='impact force (mN)', y='adhesive force (mN)', kind='scatter')

# %% [markdown]
# There does, in fact, seem to be some correlation.  We could try any pair.

# %%
df.plot(x='total contact area (mm2)', y='adhesive force (mN)', kind='scatter')

# %% [markdown]
# We can quickly compute the Pearson correlation between all pairs of data with the `corr()` method of the `DataFrame`.

# %%
df.corr()
# Out:
#                                                     trial number  \
# trial number                                            1.000000
# impact force (mN)                                       0.081059
# impact time (ms)                                       -0.012223
# impact force / body weight                             -0.165235
# adhesive force (mN)                                    -0.144249
# time frog pulls on target (ms)                         -0.300896
# adhesive force / body weight                           -0.000758
# adhesive impulse (N-s)                                 -0.152892
# total contact area (mm2)                               -0.070046
# contact area without mucus (mm2)                        0.338473
# contact area with mucus / contact area without ...     -0.487218
# contact pressure (Pa)                                   0.105460
# adhesive strength (Pa)                                 -0.228193
#
#                                                     impact force (mN)  \
# trial number                                                 0.081059
# impact force (mN)                                            1.000000
# impact time (ms)                                             0.065284
# impact force / body weight                                   0.233450
# adhesive force (mN)                                         -0.581344
# time frog pulls on target (ms)                              -0.121341
# adhesive force / body weight                                -0.282177
# adhesive impulse (N-s)                                      -0.328656
# total contact area (mm2)                                     0.436910
# contact area without mucus (mm2)                             0.447339
# contact area with mucus / contact area without ...          -0.163551
# contact pressure (Pa)                                        0.436010
# adhesive strength (Pa)                                      -0.087942
#
#                                                     impact time (ms)  \
# trial number                                               -0.012223
# impact force (mN)                                           0.065284
# impact time (ms)                                            1.000000
# impact force / body weight                                  0.060478
# adhesive force (mN)                                         0.166485
# time frog pulls on target (ms)                             -0.224467
# adhesive force / body weight                               -0.276984
# adhesive impulse (N-s)                                      0.184928
# total contact area (mm2)                                   -0.151079
# contact area without mucus (mm2)                           -0.054654
# contact area with mucus / contact area without ...         -0.001410
# contact pressure (Pa)                                       0.088254
# adhesive strength (Pa)                                     -0.010054
#
#                                                     impact force / body weight  \
# trial number                                                         -0.165235
# impact force (mN)                                                     0.233450
# impact time (ms)                                                      0.060478
# impact force / body weight                                            1.000000
# adhesive force (mN)                                                   0.313570
# time frog pulls on target (ms)                                        0.055374
# adhesive force / body weight                                          0.327074
# adhesive impulse (N-s)                                                0.303916
# total contact area (mm2)                                             -0.291663
# contact area without mucus (mm2)                                     -0.190505
# contact area with mucus / contact area without ...                   -0.084925
# contact pressure (Pa)                                                 0.397020
# adhesive strength (Pa)                                                0.089783
#
#                                                     adhesive force (mN)  \
# trial number                                                  -0.144249
# impact force (mN)                                             -0.581344
# impact time (ms)                                               0.166485
# impact force / body weight                                     0.313570
# adhesive force (mN)                                            1.000000
# time frog pulls on target (ms)                                 0.172685
# adhesive force / body weight                                  -0.017410
# adhesive impulse (N-s)                                         0.518693
# total contact area (mm2)                                      -0.517483
# contact area without mucus (mm2)                              -0.488566
# contact area with mucus / contact area without ...             0.194437
# contact pressure (Pa)                                         -0.098643
# adhesive strength (Pa)                                         0.336116
#
#                                                     time frog pulls on target (ms)  \
# trial number                                                             -0.300896
# impact force (mN)                                                        -0.121341
# impact time (ms)                                                         -0.224467
# impact force / body weight                                                0.055374
# adhesive force (mN)                                                       0.172685
# time frog pulls on target (ms)                                            1.000000
# adhesive force / body weight                                              0.006804
# adhesive impulse (N-s)                                                   -0.369147
# total contact area (mm2)                                                  0.282509
# contact area without mucus (mm2)                                         -0.262914
# contact area with mucus / contact area without ...                        0.620117
# contact pressure (Pa)                                                    -0.353474
# adhesive strength (Pa)                                                    0.434311
#
#                                                     adhesive force / body weight  \
# trial number                                                           -0.000758
# impact force (mN)                                                      -0.282177
# impact time (ms)                                                       -0.276984
# impact force / body weight                                              0.327074
# adhesive force (mN)                                                    -0.017410
# time frog pulls on target (ms)                                          0.006804
# adhesive force / body weight                                            1.000000
# adhesive impulse (N-s)                                                  0.200359
# total contact area (mm2)                                               -0.316363
# contact area without mucus (mm2)                                       -0.237184
# contact area with mucus / contact area without ...                     -0.146312
# contact pressure (Pa)                                                  -0.097282
# adhesive strength (Pa)                                                 -0.154410
#
#                                                     adhesive impulse (N-s)  \
# trial number                                                     -0.152892
# impact force (mN)                                                -0.328656
# impact time (ms)                                                  0.184928
# impact force / body weight                                        0.303916
# adhesive force (mN)                                               0.518693
# time frog pulls on target (ms)                                   -0.369147
# adhesive force / body weight                                      0.200359
# adhesive impulse (N-s)                                            1.000000
# total contact area (mm2)                                         -0.684423
# contact area without mucus (mm2)                                 -0.434937
# contact area with mucus / contact area without ...               -0.058184
# contact pressure (Pa)                                             0.224038
# adhesive strength (Pa)                                           -0.187740
#
#                                                     total contact area (mm2)  \
# trial number                                                       -0.070046
# impact force (mN)                                                   0.436910
# impact time (ms)                                                   -0.151079
# impact force / body weight                                         -0.291663
# adhesive force (mN)                                                -0.517483
# time frog pulls on target (ms)                                      0.282509
# adhesive force / body weight                                       -0.316363
# adhesive impulse (N-s)                                             -0.684423
# total contact area (mm2)                                            1.000000
# contact area without mucus (mm2)                                    0.383562
# contact area with mucus / contact area without ...                  0.310887
# contact pressure (Pa)                                              -0.390094
# adhesive strength (Pa)                                              0.417100
#
#                                                     contact area without mucus (mm2)  \
# trial number                                                                0.338473
# impact force (mN)                                                           0.447339
# impact time (ms)                                                           -0.054654
# impact force / body weight                                                 -0.190505
# adhesive force (mN)                                                        -0.488566
# time frog pulls on target (ms)                                             -0.262914
# adhesive force / body weight                                               -0.237184
# adhesive impulse (N-s)                                                     -0.434937
# total contact area (mm2)                                                    0.383562
# contact area without mucus (mm2)                                            1.000000
# contact area with mucus / contact area without ...                         -0.394482
# contact pressure (Pa)                                                       0.026032
# adhesive strength (Pa)                                                      0.007942
#
#                                                     contact area with mucus / contact area without mucus  \
# trial number                                                                                -0.487218
# impact force (mN)                                                                           -0.163551
# impact time (ms)                                                                            -0.001410
# impact force / body weight                                                                  -0.084925
# adhesive force (mN)                                                                          0.194437
# time frog pulls on target (ms)                                                               0.620117
# adhesive force / body weight                                                                -0.146312
# adhesive impulse (N-s)                                                                      -0.058184
# total contact area (mm2)                                                                     0.310887
# contact area without mucus (mm2)                                                            -0.394482
# contact area with mucus / contact area without ...                                           1.000000
# contact pressure (Pa)                                                                       -0.454396
# adhesive strength (Pa)                                                                       0.506204
#
#                                                     contact pressure (Pa)  \
# trial number                                                     0.105460
# impact force (mN)                                                0.436010
# impact time (ms)                                                 0.088254
# impact force / body weight                                       0.397020
# adhesive force (mN)                                             -0.098643
# time frog pulls on target (ms)                                  -0.353474
# adhesive force / body weight                                    -0.097282
# adhesive impulse (N-s)                                           0.224038
# total contact area (mm2)                                        -0.390094
# contact area without mucus (mm2)                                 0.026032
# contact area with mucus / contact area without ...              -0.454396
# contact pressure (Pa)                                            1.000000
# adhesive strength (Pa)                                          -0.600649
#
#                                                     adhesive strength (Pa)
# trial number                                                     -0.228193
# impact force (mN)                                                -0.087942
# impact time (ms)                                                 -0.010054
# impact force / body weight                                        0.089783
# adhesive force (mN)                                               0.336116
# time frog pulls on target (ms)                                    0.434311
# adhesive force / body weight                                     -0.154410
# adhesive impulse (N-s)                                           -0.187740
# total contact area (mm2)                                          0.417100
# contact area without mucus (mm2)                                  0.007942
# contact area with mucus / contact area without ...                0.506204
# contact pressure (Pa)                                            -0.600649
# adhesive strength (Pa)                                            1.000000

# %% [markdown]
# ### Shortcut names
# It is getting kind of cumbersome indexing with the long column headings.  The headings are nonetheless useful, since they are descriptive and we never have problems losing track of units.  But, let's say we wanted change `impact force (mN)` to `impf` for easier indexing.  We can use the `rename()` method of `DataFrame`s.  We just pass in a dictionary of columns we want to rename.

# %%
# Rename the impact force column
df = df.rename(columns={'impact force (mN)': 'impf'})

# %% [markdown]
# ### Does it matter which frog?
# Instead of pooling all the data together, we might want to look at each frog.  We'll create a beeswarm plot of the impact forces generated from each of the four frogs.

# %%
# Separate impact forces by frog
list_of_impfs = [df['impf'][df.ID=='I'], df['impf'][df.ID=='II'],
                 df['impf'][df.ID=='III'], df['impf'][df.ID=='IV']]

# Generate a beeswarm plot
beeswarm.beeswarm(list_of_impfs, labels=['I', 'II', 'III', 'IV'])
plt.ylabel('impact force (mN)')

# %% [markdown]
# We see that frog I was a big hitter, but is pretty inconsistent.  The juvenile frogs, III and IV, strike with much less force.  They're much smaller, and are actually even a different species.
#
# This plot is very simple, and using Pandas `DataFrame`s made it very easy to generate.
#
# We may want to check if frog I is moody from day to day.  So, we can plot the impact force as a function of date.  We first have to convert the strings like `'2013_02_26'` to dates that Pandas recognized.

# %%
# Convert to dates
df['date'] = pd.to_datetime(df['date'], format='%Y_%m_%d')

# Make a plot for frog I of impact force vs date
df[df['ID']=='I'].plot(x='date', y='impf', kind='line', marker='o', linestyle='',
                      legend=False)
plt.ylabel('impact force (mN)')

# %% [markdown]
# So, there does not appear to be any correlation between what day frog I strikes and how hard he or she strikes.  Remember, it was as simple as using the `df[df['ID']=='I']` syntax to pull out these data!  Pandas is a powerful ally.
