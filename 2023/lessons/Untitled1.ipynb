# %%
import numpy as np
import pandas as pd

import iqplot

import bokeh.io
import bokeh.models
import bokeh.plotting

bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b2eedadf-a989-4da5-b13c-9d7e4cdf307a">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('data/frog_tongue_adhesion.csv', comment='#')

df.head()
# Out:
#          date ID  trial number  impact force (mN)  impact time (ms)  \
# 0  2013_02_26  I             3               1205                46
# 1  2013_02_26  I             4               2527                44
# 2  2013_03_01  I             1               1745                34
# 3  2013_03_01  I             2               1556                41
# 4  2013_03_01  I             3                493                36
#
#    impact force / body weight  adhesive force (mN)  \
# 0                        1.95                 -785
# 1                        4.08                 -983
# 2                        2.82                 -850
# 3                        2.51                 -455
# 4                        0.80                 -974
#
#    time frog pulls on target (ms)  adhesive force / body weight  \
# 0                             884                          1.27
# 1                             248                          1.59
# ...

# %%
p = iqplot.ecdf(
    data=df,
    q="impact force (mN)",
    cats="ID",
    style='staircase',
)

bokeh.io.show(p)
# Out:
#   <div id="a6cb872d-13b3-4a48-9f82-83cf8a408c67" data-root-id="p5934" style="display: contents;"></div>

# %%
df_gfmt = pd.read_csv('data/gfmt_sleep.csv', na_values='*')

p = iqplot.spike(df_gfmt, q='psqi')
bokeh.io.show(p)
# Out:
#   <div id="e56edfea-b620-4a4d-9649-744c1120d0f7" data-root-id="p3998" style="display: contents;"></div>
